# %% [markdown]
# # Importing Libraries and data

# %%
import re

import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler, OrdinalEncoder, MinMaxScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

import xgboost as xgb

# %%
! unzip 'samsung_mobile_data.zip'
# Out:
# Archive:  samsung_mobile_data.zip
# replace samsungMobilesData.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: samsungMobilesData.csv
# replace samsung_mobile_new_data.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: samsung_mobile_new_data.csv

# %%
df = pd.read_csv('samsungMobilesData.csv')

# %% [markdown]
# # Taking a peek at the data

# %%
df.sample(10)
# Out:
#                                                  name  ratings  price  \
# 236                 SAMSUNG Galaxy On6 (Black, 64 GB)      4.4  17600
# 400                SAMSUNG Galaxy A10s (Black, 32 GB)      4.3  10000
# 348   SAMSUNG Galaxy A70s (Prism Crush White, 128 GB)      4.2  31000
# 246   SAMSUNG Galaxy M32 Prime Edition (Black, 64 GB)      4.2  12185
# 67          SAMSUNG Galaxy A52 (Awesome Blue, 128 GB)      4.3  25980
# 386     SAMSUNG Galaxy Note 8 (Midnight Black, 64 GB)      4.1   8464
# 273     SAMSUNG Galaxy A51 (Prism Crush Blue, 128 GB)      4.2  27999
# 133                SAMSUNG Galaxy A13 (Black, 128 GB)      4.1  14999
# 277  SAMSUNG M21 2021 Edition (Charcoal Black, 64 GB)      4.2  11530
# 12         SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)      4.3   9499
#
#                                                 imgURL  camera      display  \
# 236  https://rukminim2.flixcart.com/image/312/312/j...      13       AMOLED
# 400  https://rukminim2.flixcart.com/image/312/312/k...      13  other_types
# 348  https://rukminim2.flixcart.com/image/312/312/k...      64  other_types
# 246  https://rukminim2.flixcart.com/image/312/312/x...      64          LCD
# 67   https://rukminim2.flixcart.com/image/312/312/k...      64   HD+ AMOLED
# 386  https://rukminim2.flixcart.com/image/312/312/j...      12  other_types
# 273  https://rukminim2.flixcart.com/image/312/312/k...      13       AMOLED
# 133  https://rukminim2.flixcart.com/image/312/312/l...      50  other_types
# 277  https://rukminim2.flixcart.com/image/312/312/k...      48  other_types
# 12   https://rukminim2.flixcart.com/image/312/312/x...      50  other_types
#
#      battery  storage  ram               processor  android_version
# 236     4000       64    6           not mentioned                9
# 400     4000       32    2                MediaTek                9
# 348     4500      128    6  Snapdragon(SDM450-F01)               10
# 246     5000       32    3           not mentioned               11
# 67      4500      128    6           not mentioned               12
# 386     3300       64    6           not mentioned               10
# 273     4000      128    8           Snapdragon450                5
# 133     5000      128    4           not mentioned               12
# 277     6000       64    4           not mentioned               10
# 12      6000       64    4           not mentioned               12

# %%
df.shape
# Out:
# (407, 11)

# %%
df.isna().sum()
# Out:
# name               0
# ratings            0
# price              0
# imgURL             0
# camera             0
# display            0
# battery            0
# storage            0
# ram                0
# processor          0
# android_version    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             407 non-null    object
#  1   ratings          407 non-null    float64
#  2   price            407 non-null    int64
#  3   imgURL           407 non-null    object
#  4   camera           407 non-null    int64
#  5   display          407 non-null    object
#  6   battery          407 non-null    int64
#  7   storage          407 non-null    int64
#  8   ram              407 non-null    int64
#  9   processor        407 non-null    object
#  10  android_version  407 non-null    int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 35.1+ KB

# %% [markdown]
# # Final Cleaning of the data

# %%
df.drop('imgURL', inplace = True, axis = 1)

# %%
def get_color(row):
  matches = re.search(r'\((.*?)\)', row)  # Extracts text within parentheses
  if matches:
    x = matches.group(1).split(',')[0]
    return x.lower().split(' ')[-1]
  return None

df['color'] = df['name'].apply(get_color)

# %%
df.color.unique()
# Out:
# array(['copper', 'blue', 'green', 'purple', 'blush', 'black', 'brown',
#        'mint', 'graphite', 'lavender', 'violet', 'white', 'navy', 'peach',
#        'onyx', 'red', 'cream', 'orange', 'silver', 'bronze', 'lime',
#        'aqua', 'teal', 'gold', 'burgundy', 'graygreen', 'gray', 'grey',
#        'sand'], dtype=object)

# %%
df.sample(10)
# Out:
#                                                name  ratings  price  camera  \
# 397       SAMSUNG Galaxy M31s (Mirage Blue, 128 GB)      4.1  18999      64
# 54             SAMSUNG Galaxy A14 5G (Black, 64 GB)      4.1  15999      50
# 380              SAMSUNG Galaxy A70 (Black, 128 GB)      4.2  30900      32
# 17   SAMSUNG Galaxy M33 5G (Mystique Green, 128 GB)      4.2  16479      50
# 22   SAMSUNG Galaxy M33 5G (Mystique Green, 128 GB)      4.2  16479      50
# 327  SAMSUNG Galaxy A71 (Haze Crush Silver, 128 GB)      4.3  29499      48
# 158              SAMSUNG Galaxy A23 (Black, 128 GB)      4.3  18790      50
# 9      SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)      4.3  15499      50
# 293       SAMSUNG Galaxy A7-2017 (Gold Sand, 32 GB)      4.3  25900      64
# 398      SAMSUNG Galaxy A32 (Awesome Black, 128 GB)      4.5  24999      64
#
#          display  battery  storage  ram                processor  \
# 397  other_types     6000      128    6            not mentioned
# 54           LCD     5000       64    4            not mentioned
# 380  other_types     4500      128    6            not mentioned
# 17   other_types     6000      128    6            not mentioned
# 22   other_types     6000      128    6            not mentioned
# 327       AMOLED     4500      128    8            not mentioned
# 158  other_types     5000      128    8            not mentioned
# 9    other_types     5000      128    6  Snapdragon750GProcessor
# 293  other_types     3600       32    3            not mentioned
# 398  other_types     5000      128    6            not mentioned
#
#      android_version   color
# 397                9    blue
# 54                12   black
# 380               13   black
# 17                13   green
# 22                 1   green
# 327               12  silver
# 158               12   black
# 9                 12   blush
# 293               12    sand
# 398                9   black

# %%
def get_series(row):
  pattern = r'^(?=[a-zA-Z\d]{1,5}$)(?=[a-zA-Z])(?=.*\d).*$'

  for string in row.split(' '):
    if re.match(pattern, string):
      return string

df['series'] = df['name'].apply(get_series)

# %%
df.dropna(axis = 0, inplace =True)

# %%
df.shape
# Out:
# (393, 12)

# %%
df.sample(3)
# Out:
#                                                 name  ratings  price  camera  \
# 100       SAMSUNG Galaxy A53 (Awesome White, 128 GB)      4.0  31999      64
# 154               SAMSUNG Galaxy A22 (Black, 128 GB)      4.2  20499      48
# 246  SAMSUNG Galaxy M32 Prime Edition (Black, 64 GB)      4.2  12185      64
#
#         display  battery  storage  ram      processor  android_version  color  \
# 100  HD+ AMOLED     5000      128    6  not mentioned               12  white
# 154      AMOLED     5000      128    6    Heilo806769               11  black
# 246         LCD     5000       32    3  not mentioned               11  black
#
#     series
# 100    A53
# 154    A22
# 246    M32

# %%
df.camera.unique()
# Out:
# array([ 50,  13,   0,  48,  32,  12,   8,  64, 108,  25, 200,  24,   5,
#         16,   3])

# %%
print(df.display.value_counts())
# Out:
# other_types    239
# LCD             69
# HD+ AMOLED      42
# AMOLED          38
# TFT              5
# Name: display, dtype: int64

# %%
for i in df.columns[4:]:
  print(f'{i.title()} value_counts = \n{df[i].value_counts()}')
  print('------------------------------------------------------')
# Out:
# Display value_counts =
# other_types    239
# LCD             69
# HD+ AMOLED      42
# AMOLED          38
# TFT              5
# Name: display, dtype: int64
# ------------------------------------------------------
# Battery value_counts =
# 5000    192
# 6000     95
# 4000     27
# 4500     25
# 3700     11
# 3900      8
# 7000      7
# 3000      7
# 3300      7
# 4400      4
# 2600      4
# 3500      4
# 4700      2
# Name: battery, dtype: int64
# ------------------------------------------------------
# Storage value_counts =
# 128    216
# 64     101
# 32      40
# 256     25
# 16       6
# 1        3
# 8        1
# 512      1
# Name: storage, dtype: int64
# ------------------------------------------------------
# Ram value_counts =
# 6     126
# 4     122
# 8      82
# 3      28
# 2      18
# 12     13
# 1       4
# Name: ram, dtype: int64
# ------------------------------------------------------
# Processor value_counts =
# not mentioned              262
# MediaTek                    14
# Gen8                        14
# Dimensity1080,              12
# Dimensity700                 9
# Snapdragon720GProcessor      8
# Snapdragon1P                 8
# Snapdragon750GProcessor      7
# Heilo80P                     7
# Heilo356765                  7
# Snapdragon(SDM450-F01)       7
# Snapdragon695                5
# Snapdragon450P               5
# Dimensity720                 4
# Snapdragon888                4
# Snapdragon450                4
# Heilo35P                     4
# Snapdragon(SDM439)           4
# Heilo806769                  2
# Snapdragon750G               2
# Snapdragon425P               2
# Heilo67653512                1
# Snapdragon410                1
# Name: processor, dtype: int64
# ------------------------------------------------------
# Android_Version value_counts =
# 12    116
# 11     93
# 10     70
# 13     56
# 9      29
# 8      15
# 7       4
# 4       3
# 5       3
# 1       2
# 6       2
# Name: android_version, dtype: int64
# ------------------------------------------------------
# Color value_counts =
# black        107
# blue         102
# green         44
# white         24
# silver        16
# copper        10
# violet         9
# red            9
# gray           8
# peach          8
# mint           7
# gold           7
# brown          6
# graphite       5
# purple         4
# lavender       4
# grey           3
# cream          3
# orange         2
# lime           2
# aqua           2
# teal           2
# navy           2
# burgundy       2
# blush          2
# bronze         1
# graygreen      1
# onyx           1
# Name: color, dtype: int64
# ------------------------------------------------------
# Series value_counts =
# M32      23
# A13      15
# A14      15
# S23      13
# M13      13
#          ..
# F54       1
# Flip3     1
# J7        1
# J4        1
# M01s      1
# Name: series, Length: 76, dtype: int64
# ------------------------------------------------------

# %%
df.drop(['name','ratings'], inplace = True, axis = 1)

# %%
df.sample(3)
# Out:
#      price  camera      display  battery  storage  ram      processor  \
# 284  19000      64  other_types     6000      128    8  not mentioned
# 73   21999      50          LCD     5000      128    6  Snapdragon695
# 260  14499       5  other_types     5000      128    4  not mentioned
#
#      android_version   color series
# 284               11   black    M32
# 73                12  silver    A23
# 260               11   white    A13

# %% [markdown]
# # First Approach

# %% [markdown]
# ## Encoding

# %%
X = df.drop('price', axis = 1)
y = df['price'].copy()

# %%
encoder = OrdinalEncoder()

# %%
cat_pipeline = Pipeline([
    ('encoder', OrdinalEncoder()),
    ('std_scaler', StandardScaler())
])

num_pipeline = Pipeline([
    ('std_scaler', StandardScaler())
])

full_pipeline = ColumnTransformer([
    ('cat_pipeline', cat_pipeline, [1,5,7,8]),
    ('num_pipeline', num_pipeline, [0,2,3,4,6])
])

# %%
X_prepared = full_pipeline.fit_transform(X)

# %% [markdown]
# ## Splitting the data

# %%
X_train, X_test, y_train, y_test = train_test_split(X_prepared ,y ,test_size = 0.2, random_state = 42)

# %%
X_train.shape, X_test.shape
# Out:
# ((314, 9), (79, 9))

# %% [markdown]
# ## Defining the model and getting predictions

# %%
r_forest = RandomForestRegressor(random_state=42)
d_tree = DecisionTreeRegressor(random_state=42)
xgb_regressor = xgb.XGBRegressor(random_state = 42)

# %%
def get_metrics(y_true, y_pred):
  mse = mean_squared_error(y_true, y_pred)
  mae = mean_absolute_error(y_true, y_pred)
  acc_score = r2_score(y_true, y_pred)

  return {
      'mse': mse,
      'mae': mae,
      'rmse': np.sqrt(mse),
      'r2_score': acc_score
  }

# %%
r_forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
r_forest_pred = r_forest.predict(X_test)
get_metrics(y_test, r_forest_pred)
# Out:
# {'mse': 9379291.268285716,
#  'mae': 2184.9984409282697,
#  'rmse': 3062.5628594831674,
#  'r2_score': 0.8113503375986281}

# %%
d_tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
d_tree_pred = d_tree.predict(X_test)
get_metrics(y_test, d_tree_pred)
# Out:
# {'mse': 16618557.215189874,
#  'mae': 2278.0506329113923,
#  'rmse': 4076.5864660509624,
#  'r2_score': 0.665743911926038}

# %%
xgb_regressor.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)

# %%
boost_pred = xgb_regressor.predict(X_test)
get_metrics(y_test, boost_pred)
# Out:
# {'mse': 7931565.800042563,
#  'mae': 1885.5711283623418,
#  'rmse': 2816.30357029255,
#  'r2_score': 0.840469053823746}

# %%
import pickle

pickle.dump(xgb_regressor, open('best_samsung_price_prediction_model.pkl', 'wb'))
